# %%
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread

# %%
I = imread('/content/0a02e8cb-b715-497f-a16a-c28b3409f927___RS_HL 7432.JPG')
J = imread('/content/7b417a00-eed4-4192-9ab1-709859e6556a___JR_FrgE.S 8650.JPG')

# %%
plt.figure()
plt.subplot(121), plt.imshow(I)
plt.subplot(122), plt.imshow(J)
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.imshow(np.abs(I[:, :, 0].astype(float) - J[:, :, 0].astype(float)), cmap='gray')
plt.show()

# %%
d = imread('/content/0a02e8cb-b715-497f-a16a-c28b3409f927___RS_HL 7432.JPG')
mask = imread('/content/7b417a00-eed4-4192-9ab1-709859e6556a___JR_FrgE.S 8650.JPG')
print(np.amin(d), np.amax(d))
print(np.amin(mask), np.amax(mask))
# Out:
# 0 255
# 0 237

# %%
plt.figure(), plt.imshow(mask), plt.show()
# Out:
# (<Figure size 432x288 with 1 Axes>,
# ...
#  None)

# %%
mask = mask[:, :, 0]

# %%
maskInv = np.zeros_like(mask)
maskInv[mask == 0] = 255
maskInv[mask == 255] = 0
plt.figure(), plt.imshow(maskInv, cmap='gray'), plt.show()
# Out:
# (<Figure size 432x288 with 1 Axes>,
# ...
#  None)

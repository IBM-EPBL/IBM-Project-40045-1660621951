# %%
test_dir=r'C:\Users\kousi\Downloads\IBM\Dataset Plant Disease\Veg-dataset\Veg-dataset\test_set'

# %%
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
model = tf.keras.models.load_model(r'C:\Users\kousi\Downloads\IBM\vegetabledata.h5')

# %%
test_datagen_1=ImageDataGenerator(rescale=1)
test_generator_1=test_datagen_1.flow_from_directory(
    test_dir,
    target_size=(128,128),
    batch_size=20,
    class_mode='categorical'
)
# Out:
# Found 3416 images belonging to 9 classes.

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
img=image.load_img(r"C:\Users\kousi\Downloads\IBM\Dataset Plant Disease\Veg-dataset\Veg-dataset\train_set\Pepper,_bell___healthy\0dd09705-5593-4d01-9a9b-c1d5857daf92___JR_HL 8212.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x1B3E9CBBCD0>

# %%
img=image.load_img(r"C:\Users\kousi\Downloads\IBM\Dataset Plant Disease\Veg-dataset\Veg-dataset\train_set\Pepper,_bell___healthy\0dd09705-5593-4d01-9a9b-c1d5857daf92___JR_HL 8212.jpg",target_size=(128,128))
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
y=np.argmax(model.predict(x),axis=1)
index=['Apple___Black_rot', 'Apple___healthy', 'Corn_(maize)___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Peach___Bacterial_spot', 'Peach___healthy']
index[y[0]]
# Out:
# 1/1 [==============================] - 0s 314ms/step
# 'Apple___healthy'

# %%
model.evaluate(test_generator_1,steps=50)
# Out:
# 50/50 [==============================] - 3s 58ms/step - loss: 2565.6594 - accuracy: 0.2500
# [2565.659423828125, 0.25]
